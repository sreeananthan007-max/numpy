# %%
import numpy as np

# %%
a=np.array([[2,4],[6,8]])

# %%
b=np.array([[1,3],[5,7]])

# %%
a+b
# Out:
# array([[ 3,  7],
#        [11, 15]])

# %%
a-b
# Out:
# array([[1, 1],
#        [1, 1]])

# %%
a*b
# Out:
# array([[ 2, 12],
#        [30, 56]])

# %%
np.matmul(a,b)
# Out:
# array([[22, 34],
#        [46, 74]])

# %%
a.T
# Out:
# array([[2, 6],
#        [4, 8]])

# %%
np.linalg.det(a)
# Out:
# np.float64(-8.000000000000002)

# %%
np.linalg.inv(a)
# Out:
# array([[-1.  ,  0.5 ],
#        [ 0.75, -0.25]])

# %%
sale=np.array([[120,150,170,200],
                [130,160,180,220],
                [140,170,190,240],
                [150,180,200,260]])

# %%
sale.sum(axis=1)
# Out:
# array([640, 690, 740, 790])

# %%
sale.sum(axis=0)
# Out:
# array([540, 660, 740, 920])

# %%
sale.max()
# Out:
# np.int64(260)

# %%
sale.min()
# Out:
# np.int64(120)

# %%
sale.mean()
# Out:
# np.float64(178.75)

# %%
np.argmax(sale.sum(axis=1))+1
# Out:
# np.int64(4)

# %%
np.argmax(sale.sum(axis=0))+1
# Out:
# np.int64(4)

# %%
sale.sum()
# Out:
# np.int64(2860)

# %%
sale*1.10
# Out:
# array([[132., 165., 187., 220.],
#        [143., 176., 198., 242.],
#        [154., 187., 209., 264.],
#        [165., 198., 220., 286.]])

# %%
sale>180
