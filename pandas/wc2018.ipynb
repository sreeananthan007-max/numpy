# %%
import pandas as pd

# %%
df=pd.read_csv("wcplayerstatistics2018.csv")

# %%
df.head(10)
# Out:
#    Rk               Player Pos           Squad  Age  Born  MP  Starts  Min  \
# 0   1  Mohamed Abdel-Shafy  DF        eg Egypt   32  1985   3       3  270
# 1   2      Shehu Abdullahi  DF      ng Nigeria   25  1993   1       1   90
# 2   3        Johnny Acosta  DF   cr Costa Rica   34  1983   3       3  270
# 3   4         Marcos Acuña  MF    ar Argentina   26  1991   1       1   90
# 4   5       Luis Advíncula  DF         pe Peru   28  1990   3       3  270
# 5   6        Sergio Agüero  FW    ar Argentina   30  1988   4       2  179
# 6   7         Abel Aguilar  MF     co Colombia   33  1985   1       1   31
# 7   8      Karim El Ahmadi  MF      ma Morocco   33  1985   3       3  265
# 8   9        Manuel Akanji  DF  ch Switzerland   22  1995   4       4  360
# 9  10        Igor Akinfeev  GK       ru Russia   32  1986   5       5  510
#
#    90s  ...  PKatt  CrdY  CrdR  PlayerID  AstPer90  G+APer90  GlsPer90  \
# ...

# %%
df.tail(10)
# Out:
#       Rk            Player Pos              Squad  Age  Born  MP  Starts  Min  \
# 593  594    Kim Young-gwon  DF  kr Korea Republic   28  1990   3       3  270
# 594  595     Yun Young-sun  DF  kr Korea Republic   29  1988   1       1   90
# 595  596     Denis Zakaria  DF     ch Switzerland   21  1996   2       0   52
# 596  597   Cristián Zapata  DF        co Colombia   31  1986   1       0    5
# 597  598      Yuri Zhirkov  DF          ru Russia   34  1983   3       3  220
# 598  599   Piotr Zieliński  FW          pl Poland   24  1994   3       3  258
# 599  600  Andrija Živković  FW          rs Serbia   21  1996   1       0   16
# 600  601      Hakim Ziyech  MF         ma Morocco   25  1993   3       3  264
# 601  602      Roman Zobnin  MF          ru Russia   24  1994   5       5  510
# 602  603      Steven Zuber  MF     ch Switzerland   26  1991   3       3  251
#
#      90s  ...  PKatt  CrdY  CrdR  PlayerID  AstPer90  G+APer90  GlsPer90  \
# ...

# %%
df.shape[0]
# Out:
# 603

# %%
df.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Squad', 'Age', 'Born', 'MP', 'Starts', 'Min',
#        '90s', 'Gls', 'Ast', 'G+A', 'G-PK', 'PK', 'PKatt', 'CrdY', 'CrdR',
#        'PlayerID', 'AstPer90', 'G+APer90', 'GlsPer90', 'G-PKPer90',
#        'G+A-PKPer90', 'SecondPos'],
#       dtype='str')

# %%
df.isnull().sum()
# Out:
# Rk               0
# Player           0
# Pos              0
# Squad            0
# Age              0
# Born             0
# MP               0
# Starts           0
# Min              0
# 90s              0
# Gls              0
# Ast              0
# G+A              0
# G-PK             0
# PK               0
# PKatt            0
# CrdY             0
# CrdR             0
# PlayerID         0
# AstPer90         0
# G+APer90         0
# GlsPer90         0
# G-PKPer90        0
# G+A-PKPer90      0
# SecondPos      518
# dtype: int64

# %%
print("avg goal",df["Gls"].mean())
# Out:
# avg goal 0.2603648424543947

# %%
print("minimum goal",df["Gls"].min())
# Out:
# minimum goal 0

# %%
print("maximum goal",df["Gls"].max())
# Out:
# maximum goal 6

# %%
df.groupby("Squad").size()
# Out:
# Squad
# ar Argentina         20
# au Australia         15
# be Belgium           21
# br Brazil            18
# ch Switzerland       17
# co Colombia          20
# cr Costa Rica        20
# de Germany           20
# dk Denmark           20
# eg Egypt             16
# eng England          21
# es Spain             17
# fr France            21
# hr Croatia           21
# ir IR Iran           16
# is Iceland           17
# jp Japan             18
# kr Korea Republic    19
# ma Morocco           19
# mx Mexico            19
# ng Nigeria           16
# pa Panama            20
# pe Peru              17
# pl Poland            21
# pt Portugal          18
# rs Serbia            18
# ru Russia            19
# sa Saudi Arabia      20
# se Sweden            19
# sn Senegal           18
# tn Tunisia           23
# uy Uruguay           19
# dtype: int64

# %%
df.groupby("Pos")["Player"].size()
# Out:
# Pos
# DF    196
# FW    130
# GK     40
# MF    237
# Name: Player, dtype: int64

# %%
df.groupby("Squad")["Gls"].mean()
# Out:
# Squad
# ar Argentina         0.300000
# au Australia         0.133333
# be Belgium           0.714286
# br Brazil            0.444444
# ch Switzerland       0.294118
# co Colombia          0.300000
# cr Costa Rica        0.050000
# de Germany           0.100000
# dk Denmark           0.150000
# eg Egypt             0.125000
# eng England          0.571429
# es Spain             0.352941
# fr France            0.571429
# hr Croatia           0.619048
# ir IR Iran           0.062500
# is Iceland           0.117647
# jp Japan             0.333333
# kr Korea Republic    0.157895
# ma Morocco           0.105263
# mx Mexico            0.157895
# ng Nigeria           0.187500
# pa Panama            0.050000
# pe Peru              0.117647
# pl Poland            0.095238
# pt Portugal          0.333333
# rs Serbia            0.111111
# ru Russia            0.526316
# sa Saudi Arabia      0.100000
# se Sweden            0.263158
# sn Senegal           0.166667
# tn Tunisia           0.217391
# ...

# %%
df[df["Age"]>36]
# Out:
#       Rk              Player Pos         Squad  Age  Born  MP  Starts  Min  \
# 44    45        Felipe Baloy  DF     pa Panama   37  1981   1       0   22
# 88    89          Tim Cahill  FW  au Australia   38  1979   1       0   38
# 217  218     Essam El-Hadary  GK      eg Egypt   45  1973   1       1   90
# 250  251  Sergei Ignashevich  DF     ru Russia   38  1979   5       5  510
# 349  350      Rafael Márquez  MF     mx Mexico   39  1979   3       1   86
# 433  434          Blas Pérez  FW     pa Panama   37  1981   2       2  162
#
#      90s  ...  PKatt  CrdY  CrdR  PlayerID  AstPer90  G+APer90  GlsPer90  \
# 44   0.2  ...      0     0     0  2229d417       0.0      4.09      4.09
# 88   0.4  ...      0     0     0  e5a2dfc2       0.0      0.00      0.00
# 217  1.0  ...      0     0     0  79307650       0.0      0.00      0.00
# 250  5.7  ...      0     0     0  04f2ed4d       0.0      0.00      0.00
# 349  1.0  ...      0     0     0  ce067ffe       0.0      0.00      0.00
# ...

# %%
goalavg=(df["Gls"].mean())*100
print("goals %",goalavg)
# Out:
# goals % 26.036484245439468

# %%
df.groupby("Pos")["G+A"].sum()
# Out:
# Pos
# DF     45
# FW     85
# GK      0
# MF    133
# Name: G+A, dtype: int64

# %%
print(df["G+A"].mean())
# Out:
# 0.4361525704809287

# %%
print(df["G+A"].std())
# Out:
# 0.9116192322039463

# %%
print(df["G+A"].min())
# Out:
# 0

# %%
print(df["G+A"].max())
# Out:
# 6

# %%
df["SecondPos"] = df["SecondPos"].fillna("Unknown")
df["SecondPos"].isnull().sum()
# Out:
# np.int64(0)

# %%
df=df.drop_duplicates()
df.to_csv("wc2018_cleaned.csv", index=False)
