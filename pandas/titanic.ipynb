# %%
import pandas as pd

# %%
df=pd.read_csv("titanic.csv")

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
# 5          897         0       3
# 6          898         1       3
# 7          899         0       2
# 8          900         1       3
# 9          901         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 5                    Svensson, Mr. Johan Cervin    male  14.0      0      0
# ...

# %%
df.shape[0]
# Out:
# 418

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='str')

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
print("avg age",df["Age"].mean())
# Out:
# avg age 30.272590361445783

# %%
print("minimum age",df["Age"].min())
# Out:
# minimum age 0.17

# %%
print("maximum age",df["Age"].max())
# Out:
# maximum age 76.0

# %%
df.groupby("Sex").size()
# Out:
# Sex
# female    152
# male      266
# dtype: int64

# %%
df.groupby("Pclass")["PassengerId"].size()
# Out:
# Pclass
# 1    107
# 2     93
# 3    218
# Name: PassengerId, dtype: int64

# %%
df.groupby("Pclass")["Fare"].mean()
# Out:
# Pclass
# 1    94.280297
# 2    22.202104
# 3    12.459678
# Name: Fare, dtype: float64

# %%
df[df["Age"]>60]
# Out:
#      PassengerId  Survived  Pclass  \
# 2            894         0       2
# 13           905         0       2
# 81           973         0       1
# 96           988         1       1
# 114         1006         1       1
# 142         1034         0       1
# 152         1044         0       3
# 179         1071         1       1
# 193         1085         0       2
# 236         1128         0       1
# 305         1197         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 2                            Myles, Mr. Thomas Francis    male  62.0      0
# 13                                Howard, Mr. Benjamin    male  63.0      1
# 81                                  Straus, Mr. Isidor    male  67.0      1
# 96   Cavendish, Mrs. Tyrell William (Julia Florence...  female  76.0      1
# 114             Straus, Mrs. Isidor (Rosalie Ida Blun)  female  63.0      1
# 142                         Ryerson, Mr. Arthur Larned    male  61.0      1
# ...

# %%
df[(df["Sex"]=="female")&(df["Survived"]==1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1            893         1       3
# 4            896         1       3
# 6            898         1       3
# 8            900         1       3
# 12           904         1       1
# ..           ...       ...     ...
# 409         1301         1       3
# 410         1302         1       3
# 411         1303         1       1
# 412         1304         1       3
# 414         1306         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 1                   Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 4       Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# 6                               Connolly, Miss. Kate  female  30.0      0
# 8          Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0      0
# 12     Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# ..                                               ...     ...   ...    ...
# ...

# %%
df[df["Fare"]==df["Fare"].max()]
# Out:
#      PassengerId  Survived  Pclass  \
# 343         1235         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 343  Cardeza, Mrs. James Warburton Martinez (Charlo...  female  58.0      0
#
#      Parch    Ticket      Fare        Cabin Embarked
# 343      1  PC 17755  512.3292  B51 B53 B55        C

# %%
survived_people=(df["Survived"].mean())*100
print("survival rate=",survived_people,"%")
# Out:
# survival rate= 36.36363636363637 %

# %%
df.groupby("Sex")["Survived"].sum()
# Out:
# Sex
# female    152
# male        0
# Name: Survived, dtype: int64

# %%
df.groupby("Survived")["Age"].mean()
# Out:
# Survived
# 0    30.272732
# 1    30.272362
# Name: Age, dtype: float64

# %%
familysize=df["SibSp"]+df["Parch"]+1
print(familysize.mean())
# Out:
# 1.8397129186602872

# %%
import numpy as np
isalone= np.where(familysize==1,1,0)
print(isalone.sum())
# Out:
# 253

# %%
print(df["Fare"].mean())
# Out:
# 35.627188489208635

# %%
print(df["Fare"].median())
# Out:
# 14.4542

# %%
print(df["Fare"].std())
# Out:
# 55.907576179973844

# %%
print(df["Fare"].max())
# Out:
# 512.3292

# %%
print(df["Fare"].min())
# Out:
# 0.0

# %%
df["Age"]=df["Age"].fillna(df["Age"].median())
df["Age"].isnull().sum()
# Out:
# np.int64(0)

# %%
df=df.drop_duplicates()
df.to_csv("titanic_cleaned.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 df=df.drop_duplicates()
#       2 df.to_csv("titanic_cleaned.csv", index=False)
#
# AttributeError: 'function' object has no attribute 'drop_duplicates'
