# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
np.random.seed()
elec=np.random.randint(5000,20001,10)
clot=np.random.randint(3000,15001,10)
groc=np.random.randint(2000,10001,10)
day=["day1","day2","day3","day4","day5","day6","day7","day8","day9","day10"]
df=pd.DataFrame({"days":day,"electronics":elec,"clothing":clot,"groceries":groc})
print(df)
plt.figure
plt.plot(df["days"],df["electronics"],marker="o",label="electronics")
plt.plot(df["days"],df["clothing"],marker="o",label="clothing")
plt.plot(df["days"],df["groceries"],marker="o",label="groceries")
plt.title("sales trend over 10 days")
plt.xlabel("days")
plt.ylabel("sales")
plt.legend()
plt.show()
catagories=["electronics","clothing","groceries"]
avg=[df["electronics"],df["clothing"],df["groceries"]]
plt.figure
plt.bar(catagories,avg,color=["red","blue","green"])
plt.title("avg sales")
plt.xlabel("catagories")
plt.ylabel("avg")
plt.show()
df[total_sale]=df["electronics"]+df["clothing"]+df["groceries"]
print("best day of sale:")
print(df.loc[total_sale.idxmax(),"days"])
print("Lowest day:")
print(df.loc[total_sale.idxmin(),"days"])
print("top catagory:")
print(avg.idxmax())
# Out:
#     days  electronics  clothing  groceries
# 0   day1        10912      5799       6720
# 1   day2         7124     11500       7988
# 2   day3        14246     13236       4933
# 3   day4        18785      5124       9187
# 4   day5        17342     14722       5854
# 5   day6         6525      3413       7141
# 6   day7        15596     12086       6826
# 7   day8         7370      6650       9288
# 8   day9        17976      3832       6503
# 9  day10         7093      9372       7148
# best day of sale:
# day4
# Lowest day:
# day7
# top catagory
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 31
#      27 print(df.loc[total_sale.idxmax(),"days"])
#      28 print("Lowest day:")
#      29 print(df.loc[total_sale.idxmin(),"days"])
#      30 print("top catagory")
# ---> 31 print(avg.idxmax())
#
# AttributeError: 'list' object has no attribute 'idxmax'
